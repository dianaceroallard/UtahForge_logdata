# %% [markdown]
# ## UTAH FORGE  MT Data
#
# #### Data from
# #### Utah FORGE: MT Stations and Raw Data (https://gdr.openei.org/submissions/712)
# #### Utah FORGE Phase 3 Magnetotelluric (MT) Data (https://gdr.openei.org/submissions/1255)
#
#
# ### ALL the data was uploaded in the geotermaldata bucket in AWS "s3://geotermaldata/S3UTAHFORGEDATA/MT-geophysical-data/"
#
#
# #### Reminder: S3 must be installed (pip install s3 )

# %%
import pandas as pd

# %% [markdown]
# #### Importing file "Task_1_3_3_Hardwick_03_09_2016_MT_v1.txt"  part of the folder Milford Raw MT Data

# %%
MT_Mildford_data= pd.read_csv('s3://geotermaldata/S3UTAHFORGEDATA/MT-geophysical-data/MilfordMT_raw/Task_1_3_3_Hardwick_03_09_2016_MT_v1.txt', 
                              delimiter=' ', skiprows=6)

# %%
MT_Mildford_data
# Out:
#         UTMeast     UTMnorth  Elev          Freq         Rhoxx      RhoxxErr  \
# 0    333608.000  4292084.000  1478    200.000000  5.131000e-03  3.939000e-03
# 1    333608.000  4292084.000  1478    150.000000  6.399000e-03  3.939000e-03
# 2    333608.000  4292084.000  1478    100.000000  9.441000e-03  3.939000e-03
# 3    333608.000  4292084.000  1478     75.000000      0.018420  3.939000e-03
# 4    333608.000  4292084.000  1478     50.000000      0.029980  3.939000e-03
# ..          ...          ...   ...           ...           ...           ...
# 794  359677.563  4295635.500     0  2.700000e-03      0.284700      0.012814
# 795  359677.563  4295635.500     0  2.100000e-03      0.224200      0.018639
# 796  359677.563  4295635.500     0  1.500000e-03      0.269300      0.019774
# 797  359677.563  4295635.500     0  1.100000e-03      0.315500      0.028304
# 798  359677.563  4295635.500     0  8.000000e-04      0.342800      0.038678
#
# ...
