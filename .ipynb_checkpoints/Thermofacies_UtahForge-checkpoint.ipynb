# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import lasio
import petropy as ptr

# %%
logs = lasio.read(r'58-32_main.las')
#logsdf=pd.DataFrame(logs.data,columns=list(logs.curvesdict.keys()))
logs.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9d0d5ea3a05e> in <module>
#       1 logs = lasio.read(r'58-32_main.las')
#       2 #logsdf=pd.DataFrame(logs.data,columns=list(logs.curvesdict.keys()))
# ----> 3 logs.head()
#
# AttributeError: 'LASFile' object has no attribute 'head'

# %%
#TO FIX 
file_path = r'58-32_main.las'
log = ptr.Log(file_path)
log.tops_from_csv('58-32_tops.csv')
print(log.tops)
# Out:
# {'Basin Fill': 1007.0, 'Granitiod': 2296.9}

# %%
coredata_therm = pd.read_csv ('58-32_thermal_conductivity_data.csv') 
coredata_therm.head()
# Out:
#    Lower Depth Interval (m)  Upper Depth Interval (m)  \
# 0                      30.5                      33.5
# 1                      61.0                      64.0
# 2                      91.4                      94.5
# 3                     121.9                     125.0
# 4                     152.4                     155.4
#
#    matrix thermal conductivity (W/m deg C)
# 0                                     3.00
# 1                                     3.18
# 2                                     3.30
# 3                                     3.00
# 4                                     3.00

# %%
subdata = logsdf[['DEPT','GR', 'SP','RHOZ','AT90', 'CTEM']]
subdata.head()
# Out:
#    DEPT        GR  SP    RHOZ     AT90      CTEM
# 0  10.5  160.0384 NaN  2.2207  19.7369  141.8353
# 1  11.0  160.0384 NaN  2.2207  19.7369  141.8353
# 2  11.5  160.0384 NaN  2.2207  19.7369  141.8353
# 3  12.0  160.0384 NaN  2.2207  19.7369  141.8353
# 4  12.5  160.0384 NaN  2.2207  19.7369  141.8353

# %%
data = subdata.values
rows, cols = 1,5
fig,ax = plt.subplots(nrows=rows, ncols=cols, figsize=(12,10), sharey=True)

mnemonics = ['GR', 'SP','RHOZ','AT90', 'CTEM']
for i in range(cols):
    ax[i].plot(data[:,i+1], data[:,0],linewidth='0.5')
    ax[i].set_ylim(max(data[:, 0]), min(data[:, 0]))
    ax[i].minorticks_on()
    ax[i].grid(which='major', linestyle='-', linewidth='0.5', color='green')
    ax[i].grid(which='minor', linestyle=':', linewidth='0.5', color='black') 
    ax[i].set_title('%s' %mnemonics[i])
    
y2 = data[:, 1]
y1 = y2*0+80
ax[0].fill_betweenx(data[:, 0], y1,y2, where=(y1>=y2), color='gold', linewidth=0)
ax[0].fill_betweenx(data[:, 0], y1,y2, where=(y1< y2), color='lime', linewidth=0)
plt.subplots_adjust(wspace=0)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') # to give the plot a style
GR = [40, 20, 25, 26, 23, 30, 42, 130, 135, 140, 135] # Gamma-ray data
Depth = [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1010, 1011] # Depth
plt.plot(GR, Depth, "r o", label ="Gamma-ray") # ploting the gamma-ray vs Depth
plt.gca().invert_yaxis() # inversing depth
plt.legend() # showing legend
plt.show()

# %%
# %load functioname.py
